# %% [markdown]
# # Progetto Foundations of Computer Science
# ## Anno accademico 2021-22
# ### Elisa Bernasconi 815551, Damiano Garofoli 837589, Susanna Maugeri 839365

# %% [markdown]
# You have to work on the files:
# *  [Books](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/Books.csv.gz)
# *  [Book ratings](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/Book-Ratings.csv.gz)
# *  [Users](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/Users.csv.gz)
# *  [Goodbooks books](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/goodbooks.csv.gz)
# *  [Goodbooks ratings](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/goodbooks-ratings.csv.gz)
#
# ### Notes
#
# 1.    It is mandatory to use GitHub for developing the project.
# 1.    The project must be a jupyter notebook.
# 1.    There is no restriction on the libraries that can be used, nor on the Python version.
# 1.    To read those files, you need to use the `encoding = 'latin-1'` option.
# 1.    All questions on the project **must** be asked in a public channel on [Zulip](https://focs.zulipchat.com), otherwise no  answer will be given.

# %% [markdown]
# ### Importazione della libreria pandas e dei dataset necessari

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Iniziamo con l'importazione dei file .csv.

# %%
books = pd.read_csv("Data/Books.csv", encoding = 'latin-1', sep=';', low_memory=False, header=0)
books.tail(50)
# Out:
#               ISBN                                         Book-Title  \
# 271309  0062554905  The color of light: Meditations for all of us ...
# 271310  0304329045  How Can You Write a Poem When You Are Dying of...
# 271311  0671015885               Star Trek: First Contact (Star Trek)
# 271312  1555831141                                             Chrome
# 271313  1563332442  Two Thousand Sixty-Nine: A Science Fiction Tri...
# 271314  1902852036                                All the Queen's Men
# 271315  0441011799                                    Singularity Sky
# 271316  359610601X  Der gelbe Stern: Die Judenvernichtung in Europ...
# 271317  0375415343                                  A Whistling Woman
# 271318  3404204433                           Am Ende des Regenbogens.
# 271319  3462017942              Die Massenpsychologie des Faschismus.
# 271320  3453047192  Die amerikanische Zumutung: PlÃÂ¤doyers gegen...
# 271321  9813056398      Broken Mirror : True Stories About Drug Abuse
# 271322  000637610X                                   You Got an Ology
# 271323  0878576568              Biopotency: A Guide in Sexual Success
# 271324  0747204020                  Illustrated Encyclopedia of Cacti
# 271325  0070542023                       Basic Scientific Subroutines
# 271326  0070704309                  Electronic filter design handbook
# 271327  0471915645  Introductory Digital Signal Processing with Co...
# 271328  8420614556  Lewis Carroll: A Traves Del Espejo Y Lo Que Al...
# 271329  3320016822  Urteil ohne Prozess: Margot Honecker gegen Oss...
# 271330  3423200944  Hokuspokus, liebe mich. Und fÃ?ÃÂ¼nfzig ande...
# 271331  3453065123  Ich war Hitlerjunge Salomon. ( erlebt und erfa...
# 271332  3525335423                Das Deutsche Kaiserreich 1871-1918.
# 271333  3548740146  Wicca. Eine EinfÃ?ÃÂ¼hrung in weiÃ?Ã?e Magie.
# 271334  381440176X  Ein Fall fÃ?ÃÂ¼r TKKG, Bd.50, Sklaven fÃ?Ã...
# 271335  3893312307  Die Vereinten Nationen: Zwischen Anspruch und ...
# 271336  0971854823  The Female Power Within: A Guide to Living a G...
# 271337  0316640786  Christie's Collectables: Blue and White China ...
# 271338  3257217323                       Schmatz. Oder Die Sackgasse.
# 271339  3596156904                                              Amok.
# 271340  1874166633  Introducing Nietzsche (Foundations in Children...
# 271341  0130897930                 Core Web Programming (2nd Edition)
# 271342  020130998X  The Unified Modeling Language Reference Manual...
# 271343  2268032019         Petite histoire de la dÃ?ÃÂ©sinformation
# 271344  0684860112        Driving to Detroit: Memoirs of a Fast Woman
# 271345  0395264707                                         Dreamsnake
# 271346  3442150663                                        Der Mossad.
# 271347  0231128444                      Slow Food(The Case For Taste)
# 271348  0520242335  Strong Democracy : Participatory Politics for ...
# 271349  0762412119  Burpee Gardening Cyclopedia: A Concise, Up to ...
# 271350  1582380805  Tropical Rainforests: 230 Species in Full Colo...
# 271351  1845170423                                  Cocktail Classics
# 271352  014002803X                                  Anti Death League
# 271353  0449906736      Flashpoints: Promise and Peril in a New World
# 271354  0440400988                         There's a Bat in Bunk Five
# 271355  0525447644                            From One to One Hundred
# 271356  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271357  0192126040                        Republic (World's Classics)
# 271358  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                     Book-Author Year-Of-Publication  \
# 271309          Perry Tilleraas                1988
# 271310              John Harold                1994
# 271311             J.M. Dillard                1997
# 271312             George Nadar                1987
# 271313           Larry Townsend                1995
# 271314              Nick Elwood                1999
# 271315           Charles Stross                2004
# 271316     Gerhard Schoenberner                1991
# 271317               A.S. BYATT                2002
# 271318         Alan Dean Foster                2002
# 271319            Wilhelm Reich                1986
# 271320              Rolf Winter                1990
# 271321                 Dawn Tan                2000
# 271322           Maureen Lipman                1990
# 271323            Ricard Berger                1987
# 271324            Glass Charles                1991
# 271325         Fred Ruckdeschel                1981
# 271326  Arthur Bernard Williams                1981
# 271327             Paul A. Lynn                1989
# 271328            Lewis Carroll                1986
# 271329      JÃÂ¶rn Kalkbrenner                1990
# 271330             Helen Glisic                1997
# 271331              Sally Perel                1993
# 271332       Hans-Ulrich Wehler                1994
# 271333         Scott Cunningham                2001
# 271334              Stefan Wolf                1989
# 271335         GÃÂ¼nther Unser                1995
# 271336           Marilyn Graman                2002
# 271337             Paul Tippett                1997
# 271338   Hans Werner Kettenbach                2003
# 271339         Emmanuel Carrere                2003
# 271340            Laurence Gane                1998
# 271341               Marty Hall                2001
# 271342           James Rumbaugh                1998
# 271343         Vladimir Volkoff                1999
# 271344          Lesley Hazleton                1999
# 271345        Vonda N. McIntyre                1978
# 271346         Victor Ostrovsky                2000
# 271347            Carlo Petrini                2003
# 271348       Benjamin R. Barber                2004
# 271349           Allan Armitage                2002
# 271350    Allen M., Ph.D. Young                2001
# 271351              David Biggs                2004
# 271352            Kingsley Amis                1975
# 271353             Robin Wright                1993
# 271354           Paula Danziger                1988
# 271355               Teri Sloat                1991
# 271356         Christine Wicker                2004
# 271357                    Plato                1996
# 271358      Christopher  Biffle                2000
#
#                                                Publisher  \
# 271309                                  Harper &amp; Row
# 271310                                           Cassell
# 271311             Simon &amp; Schuster (Trade Division)
# 271312                                    Carrier Pigeon
# 271313                                            Badboy
# 271314                                   Gay Men's Press
# 271315                                               Ace
# 271316                                           Fischer
# 271317                                             Knopf
# 271318                                       LÃ?ÃÂ¼bbe
# 271319                          Kiepenheuer &amp; Witsch
# 271320                                          W. Heyne
# 271321                                     Angsana Books
# 271322                          HarperCollins Publishers
# 271323                                     St Martins Pr
# 271324                                          Headline
# 271325                                        Byte Books
# 271326                                       McGraw-Hill
# 271327                             John Wiley &amp; Sons
# 271328                            Lectorum Pubns (Adult)
# 271329                                             Dietz
# 271330                                               Dtv
# 271331                                             Heyne
# 271332                        Vandenhoeck &amp; Ruprecht
# 271333                              Ullstein TB-Vlg., B.
# 271334                                           Pelikan
# 271335          Bundeszentrale fÃÂ¼r Politische Bildung
# 271336                                  Life Works Books
# 271337                              Time Warner Books UK
# 271338                                   Diogenes Verlag
# 271339                          Fischer (Tb.), Frankfurt
# 271340                                 Natl Book Network
# 271341                                 Prentice Hall PTR
# 271342                       Addison-Wesley Professional
# 271343                                Editions du Rocher
# 271344             Simon &amp; Schuster (Trade Division)
# 271345                                  Houghton Mifflin
# 271346                                          Goldmann
# 271347                         Columbia University Press
# 271348                    University of California Press
# 271349                     Running Press Book Publishers
# 271350             Golden Guides from St. Martin's Press
# 271351                                         Connaught
# 271352                                      Viking Press
# 271353                                  Ballantine Books
# 271354                   Random House Childrens Pub (Mm)
# 271355                                      Dutton Books
# 271356                                HarperSanFrancisco
# 271357                           Oxford University Press
# 271358  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 271309  http://images.amazon.com/images/P/0062554905.0...
# 271310  http://images.amazon.com/images/P/0304329045.0...
# 271311  http://images.amazon.com/images/P/0671015885.0...
# 271312  http://images.amazon.com/images/P/1555831141.0...
# 271313  http://images.amazon.com/images/P/1563332442.0...
# 271314  http://images.amazon.com/images/P/1902852036.0...
# 271315  http://images.amazon.com/images/P/0441011799.0...
# 271316  http://images.amazon.com/images/P/359610601X.0...
# 271317  http://images.amazon.com/images/P/0375415343.0...
# 271318  http://images.amazon.com/images/P/3404204433.0...
# 271319  http://images.amazon.com/images/P/3462017942.0...
# 271320  http://images.amazon.com/images/P/3453047192.0...
# 271321  http://images.amazon.com/images/P/9813056398.0...
# 271322  http://images.amazon.com/images/P/000637610X.0...
# 271323  http://images.amazon.com/images/P/0878576568.0...
# 271324  http://images.amazon.com/images/P/0747204020.0...
# 271325  http://images.amazon.com/images/P/0070542023.0...
# 271326  http://images.amazon.com/images/P/0070704309.0...
# 271327  http://images.amazon.com/images/P/0471915645.0...
# 271328  http://images.amazon.com/images/P/8420614556.0...
# 271329  http://images.amazon.com/images/P/3320016822.0...
# 271330  http://images.amazon.com/images/P/3423200944.0...
# 271331  http://images.amazon.com/images/P/3453065123.0...
# 271332  http://images.amazon.com/images/P/3525335423.0...
# 271333  http://images.amazon.com/images/P/3548740146.0...
# 271334  http://images.amazon.com/images/P/381440176X.0...
# 271335  http://images.amazon.com/images/P/3893312307.0...
# 271336  http://images.amazon.com/images/P/0971854823.0...
# 271337  http://images.amazon.com/images/P/0316640786.0...
# 271338  http://images.amazon.com/images/P/3257217323.0...
# 271339  http://images.amazon.com/images/P/3596156904.0...
# 271340  http://images.amazon.com/images/P/1874166633.0...
# 271341  http://images.amazon.com/images/P/0130897930.0...
# 271342  http://images.amazon.com/images/P/020130998X.0...
# 271343  http://images.amazon.com/images/P/2268032019.0...
# 271344  http://images.amazon.com/images/P/0684860112.0...
# 271345  http://images.amazon.com/images/P/0395264707.0...
# 271346  http://images.amazon.com/images/P/3442150663.0...
# 271347  http://images.amazon.com/images/P/0231128444.0...
# 271348  http://images.amazon.com/images/P/0520242335.0...
# 271349  http://images.amazon.com/images/P/0762412119.0...
# 271350  http://images.amazon.com/images/P/1582380805.0...
# 271351  http://images.amazon.com/images/P/1845170423.0...
# 271352  http://images.amazon.com/images/P/014002803X.0...
# 271353  http://images.amazon.com/images/P/0449906736.0...
# 271354  http://images.amazon.com/images/P/0440400988.0...
# 271355  http://images.amazon.com/images/P/0525447644.0...
# 271356  http://images.amazon.com/images/P/006008667X.0...
# 271357  http://images.amazon.com/images/P/0192126040.0...
# 271358  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 271309  http://images.amazon.com/images/P/0062554905.0...
# 271310  http://images.amazon.com/images/P/0304329045.0...
# 271311  http://images.amazon.com/images/P/0671015885.0...
# 271312  http://images.amazon.com/images/P/1555831141.0...
# 271313  http://images.amazon.com/images/P/1563332442.0...
# 271314  http://images.amazon.com/images/P/1902852036.0...
# 271315  http://images.amazon.com/images/P/0441011799.0...
# 271316  http://images.amazon.com/images/P/359610601X.0...
# 271317  http://images.amazon.com/images/P/0375415343.0...
# 271318  http://images.amazon.com/images/P/3404204433.0...
# 271319  http://images.amazon.com/images/P/3462017942.0...
# 271320  http://images.amazon.com/images/P/3453047192.0...
# 271321  http://images.amazon.com/images/P/9813056398.0...
# 271322  http://images.amazon.com/images/P/000637610X.0...
# 271323  http://images.amazon.com/images/P/0878576568.0...
# 271324  http://images.amazon.com/images/P/0747204020.0...
# 271325  http://images.amazon.com/images/P/0070542023.0...
# 271326  http://images.amazon.com/images/P/0070704309.0...
# 271327  http://images.amazon.com/images/P/0471915645.0...
# 271328  http://images.amazon.com/images/P/8420614556.0...
# 271329  http://images.amazon.com/images/P/3320016822.0...
# 271330  http://images.amazon.com/images/P/3423200944.0...
# 271331  http://images.amazon.com/images/P/3453065123.0...
# 271332  http://images.amazon.com/images/P/3525335423.0...
# 271333  http://images.amazon.com/images/P/3548740146.0...
# 271334  http://images.amazon.com/images/P/381440176X.0...
# 271335  http://images.amazon.com/images/P/3893312307.0...
# 271336  http://images.amazon.com/images/P/0971854823.0...
# 271337  http://images.amazon.com/images/P/0316640786.0...
# 271338  http://images.amazon.com/images/P/3257217323.0...
# 271339  http://images.amazon.com/images/P/3596156904.0...
# 271340  http://images.amazon.com/images/P/1874166633.0...
# 271341  http://images.amazon.com/images/P/0130897930.0...
# 271342  http://images.amazon.com/images/P/020130998X.0...
# 271343  http://images.amazon.com/images/P/2268032019.0...
# 271344  http://images.amazon.com/images/P/0684860112.0...
# 271345  http://images.amazon.com/images/P/0395264707.0...
# 271346  http://images.amazon.com/images/P/3442150663.0...
# 271347  http://images.amazon.com/images/P/0231128444.0...
# 271348  http://images.amazon.com/images/P/0520242335.0...
# 271349  http://images.amazon.com/images/P/0762412119.0...
# 271350  http://images.amazon.com/images/P/1582380805.0...
# 271351  http://images.amazon.com/images/P/1845170423.0...
# 271352  http://images.amazon.com/images/P/014002803X.0...
# 271353  http://images.amazon.com/images/P/0449906736.0...
# 271354  http://images.amazon.com/images/P/0440400988.0...
# 271355  http://images.amazon.com/images/P/0525447644.0...
# 271356  http://images.amazon.com/images/P/006008667X.0...
# 271357  http://images.amazon.com/images/P/0192126040.0...
# 271358  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 271309  http://images.amazon.com/images/P/0062554905.0...
# 271310  http://images.amazon.com/images/P/0304329045.0...
# 271311  http://images.amazon.com/images/P/0671015885.0...
# 271312  http://images.amazon.com/images/P/1555831141.0...
# 271313  http://images.amazon.com/images/P/1563332442.0...
# 271314  http://images.amazon.com/images/P/1902852036.0...
# 271315  http://images.amazon.com/images/P/0441011799.0...
# 271316  http://images.amazon.com/images/P/359610601X.0...
# 271317  http://images.amazon.com/images/P/0375415343.0...
# 271318  http://images.amazon.com/images/P/3404204433.0...
# 271319  http://images.amazon.com/images/P/3462017942.0...
# 271320  http://images.amazon.com/images/P/3453047192.0...
# 271321  http://images.amazon.com/images/P/9813056398.0...
# 271322  http://images.amazon.com/images/P/000637610X.0...
# 271323  http://images.amazon.com/images/P/0878576568.0...
# 271324  http://images.amazon.com/images/P/0747204020.0...
# 271325  http://images.amazon.com/images/P/0070542023.0...
# 271326  http://images.amazon.com/images/P/0070704309.0...
# 271327  http://images.amazon.com/images/P/0471915645.0...
# 271328  http://images.amazon.com/images/P/8420614556.0...
# 271329  http://images.amazon.com/images/P/3320016822.0...
# 271330  http://images.amazon.com/images/P/3423200944.0...
# 271331  http://images.amazon.com/images/P/3453065123.0...
# 271332  http://images.amazon.com/images/P/3525335423.0...
# 271333  http://images.amazon.com/images/P/3548740146.0...
# 271334  http://images.amazon.com/images/P/381440176X.0...
# 271335  http://images.amazon.com/images/P/3893312307.0...
# 271336  http://images.amazon.com/images/P/0971854823.0...
# 271337  http://images.amazon.com/images/P/0316640786.0...
# 271338  http://images.amazon.com/images/P/3257217323.0...
# 271339  http://images.amazon.com/images/P/3596156904.0...
# 271340  http://images.amazon.com/images/P/1874166633.0...
# 271341  http://images.amazon.com/images/P/0130897930.0...
# 271342  http://images.amazon.com/images/P/020130998X.0...
# 271343  http://images.amazon.com/images/P/2268032019.0...
# 271344  http://images.amazon.com/images/P/0684860112.0...
# 271345  http://images.amazon.com/images/P/0395264707.0...
# 271346  http://images.amazon.com/images/P/3442150663.0...
# 271347  http://images.amazon.com/images/P/0231128444.0...
# 271348  http://images.amazon.com/images/P/0520242335.0...
# 271349  http://images.amazon.com/images/P/0762412119.0...
# 271350  http://images.amazon.com/images/P/1582380805.0...
# 271351  http://images.amazon.com/images/P/1845170423.0...
# 271352  http://images.amazon.com/images/P/014002803X.0...
# 271353  http://images.amazon.com/images/P/0449906736.0...
# 271354  http://images.amazon.com/images/P/0440400988.0...
# 271355  http://images.amazon.com/images/P/0525447644.0...
# 271356  http://images.amazon.com/images/P/006008667X.0...
# 271357  http://images.amazon.com/images/P/0192126040.0...
# 271358  http://images.amazon.com/images/P/0767409752.0...

# %%
book_rat = pd.read_csv("Data/Book-Ratings.csv", encoding = 'latin-1', sep=';', low_memory=False, header=0)
book_rat.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
users = pd.read_csv("Data/Users.csv", encoding = 'latin-1', sep=';', low_memory=False, header=0)
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
good_book = pd.read_csv("Data/goodbooks.csv", sep=',', encoding = 'latin-1', low_memory=False, header=0)
good_book.tail(50)
# Out:
#     book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 49       50              30119         30119     30518           45
# 50       51             256683        256683   2267189          178
# 51       52             428263        428263   2675454          185
# 52       53             113436        113436   3178011          217
# 53       54                 11        386162   3078186          257
# 54       55               5129          5129   3204877          515
# 55       56            1162543       1162543   2960529          183
# 56       57              37435         37435   3275013          125
# 57       58               2956          2956   1835605         2277
# 58       59              24178         24178    987048          180
# 59       60               1618          1618   4259809          183
# 60       61           22557272      22557272  41107568           14
# 61       62             119322        119322   1536771          287
# 62       63               6185          6185   1565818         2498
# 63       64              10917         10917   1639903          125
# 64       65               4981          4981   1683562          241
# 65       66              18405         18405   3358283          409
# 66       67             128029        128029   3271379          197
# 67       68              22628         22628   2236198          128
# 68       69           11735983      11735983  15524542          164
# 69       70             375802        375802   2422333          224
# 70       71              18490         18490   4836639         2618
# 71       72              11588         11588    849585          289
# 72       73            1656001       1656001   3328799          161
# 73       74              99561         99561    919292          187
# 74       75             227443        227443   3185154          193
# 75       76              14935         14935   2809709         1969
# 76       77              38709         38709   1679789          138
# 77       78               5139          5139     38765          129
# 78       79               1381          1381   3356006         1703
# 79       80             157993        157993   2180358         1708
# 80       81               7445          7445   2944133           92
# 81       82               1845          1845   3284484          108
# 82       83               1953          1953   2956372          525
# 83       84               7677       6424171   3376836          176
# 84       85             370493        370493     30530           81
# 85       86              32542         32542   1804929          158
# 86       87               1617          1617    265616          109
# 87       88            6442769       6442769   3364505          178
# 88       89              21787         21787    992628          129
# 89       90             231804        231804   1426690          156
# 90       91            6186357       6186357   6366642          147
# 91       92               1202          1202      5397          124
# 92       93               2998          2998   3186437         1350
# 93       94                320           320   3295655          555
# 94       95               5297          5297   1858012         2303
# 95       96           13536860      13536860  18034963          133
# 96       97              17245         17245   3165724         2207
# 97       98            5060378       5060378   6976108          209
# 98       99           11857408      11857408  16813814          147
#
#           isbn        isbn13  \
# 49    60513039  9.780061e+12
# 50  1416914285  9.781417e+12
# 51   316160202  9.780316e+12
# 52   375826696  9.780376e+12
# 53   345391802  9.780345e+12
# 54    60929871  9.780061e+12
# 55  031606792X  9.780316e+12
# 56   142001740  9.780142e+12
# 57   142437174  9.780142e+12
# 58    64410935  9.780064e+12
# 59  1400032717  9.781400e+12
# 60  1594633665  9.781595e+12
# 61   679879242  9.780680e+12
# 62   393978893  9.780394e+12
# 63   743454537  9.780743e+12
# 64   385333846  9.780385e+12
# 65   446675539  9.780447e+12
# 66  1594489505  9.781594e+12
# 67   671027344  9.780671e+12
# 68     7442912  9.780007e+12
# 69   812550706  9.780813e+12
# 70   141439475  9.780141e+12
# 71   450040186  9.780450e+12
# 72   316068047  9.780316e+12
# 73   142402516  9.780142e+12
# 74  014028009X  9.780140e+12
# 75   141439661  9.780141e+12
# 76   439244196  9.780439e+12
# 77   307275558  9.780307e+12
# 78   143039954  9.780143e+12
# 79   156012197  9.780156e+12
# 80  074324754X  9.780743e+12
# 81   385486804  9.780385e+12
# 82   141439602  9.780141e+12
# 83  030734813X  9.780307e+12
# 84    60256656  9.780060e+12
# 85   385338600  9.780385e+12
# 86   374500010  9.780375e+12
# 87  014241493X  9.780142e+12
# 88   345418263  9.780345e+12
# 89  014038572X  9.780140e+12
# 90   385737947  9.780386e+12
# 91    61234001  9.780061e+12
# 92   517189607  9.780517e+12
# 93    60531045  9.780061e+12
# 94   375751513  9.780376e+12
# 95   345803507  9.780346e+12
# 96   393970124  9.780394e+12
# 97   307269981  9.780307e+12
# 98  1612130585  9.781612e+12
#
#                                               authors  \
# 49                                   Shel Silverstein
# 50                                    Cassandra Clare
# 51                                    Stephenie Meyer
# 52                                Christopher Paolini
# 53                                      Douglas Adams
# 54                                      Aldous Huxley
# 55                                    Stephenie Meyer
# 56                                      Sue Monk Kidd
# 57              Mark Twain, John Seelye, Guy Cardwell
# 58         E.B. White, Garth Williams, Rosemary Wells
# 59                                        Mark Haddon
# 60                                      Paula Hawkins
# 61                                     Philip Pullman
# 62                     Emily BrontÃ«, Richard J. Dunn
# 63                                       Jodi Picoult
# 64                                  Kurt Vonnegut Jr.
# 65                                  Margaret Mitchell
# 66                                    Khaled Hosseini
# 67                                    Stephen Chbosky
# 68                                      Veronica Roth
# 69                                   Orson Scott Card
# 70  Mary Wollstonecraft Shelley, Percy Bysshe Shel...
# 71                                       Stephen King
# 72                                    Stephenie Meyer
# 73                                         John Green
# 74                                     Helen Fielding
# 75            Jane Austen, Tony Tanner, Ros Ballaster
# 76                         Louis Sachar, Louis Sachar
# 77                                  Lauren Weisberger
# 78  Homer, Robert Fagles, E.V. Rieu, FrÃ©dÃ©ric Mu...
# 79  Antoine de Saint-ExupÃ©ry, Richard Howard, Dom...
# 80                                    Jeannette Walls
# 81                                       Jon Krakauer
# 82  Charles Dickens, Richard Maxwell, Hablot Knigh...
# 83                                   Michael Crichton
# 84                                   Shel Silverstein
# 85                                       John Grisham
# 86                         Elie Wiesel, Marion Wiesel
# 87                                         John Green
# 88                                    William Goldman
# 89                                        S.E. Hinton
# 90                                      James Dashner
# 91                Steven D. Levitt, Stephen J. Dubner
# 92                            Frances Hodgson Burnett
# 93          Gabriel GarcÃ­a MÃ¡rquez, Gregory Rabassa
# 94                     Oscar Wilde, Jeffrey Eugenides
# 95                                         E.L. James
# 96          Bram Stoker, Nina Auerbach, David J. Skal
# 97                         Stieg Larsson, Reg Keeland
# 98                                         E.L. James
#
#     original_publication_year  \
# 49                     1974.0
# 50                     2007.0
# 51                     2007.0
# 52                     2002.0
# 53                     1979.0
# 54                     1932.0
# 55                     2008.0
# 56                     2001.0
# 57                     1884.0
# 58                     1952.0
# 59                     2003.0
# 60                     2015.0
# 61                     1995.0
# 62                     1847.0
# 63                     2004.0
# 64                     1969.0
# 65                     1936.0
# 66                     2007.0
# 67                     1999.0
# 68                     2012.0
# 69                     1985.0
# 70                     1818.0
# 71                     1977.0
# 72                     2008.0
# 73                     2005.0
# 74                     1996.0
# 75                     1811.0
# 76                     1998.0
# 77                     2003.0
# 78                     -720.0
# 79                     1946.0
# 80                     2005.0
# 81                     1996.0
# 82                     1859.0
# 83                     1990.0
# 84                     1964.0
# 85                     1989.0
# 86                     1958.0
# 87                     2008.0
# 88                     1973.0
# 89                     1967.0
# 90                     2009.0
# 91                     2005.0
# 92                     1911.0
# 93                     1967.0
# 94                     1891.0
# 95                     2012.0
# 96                     1897.0
# 97                     2006.0
# 98                     2011.0
#
#                                        original_title  ... ratings_count  \
# 49  Where the Sidewalk Ends: The Poems and Drawing...  ...       1016888
# 50                                      City of Bones  ...       1154031
# 51                                            Eclipse  ...       1134511
# 52                                             Eragon  ...       1104021
# 53               The Hitchhiker's Guide to the Galaxy  ...        936782
# 54                                    Brave New World  ...       1022601
# 55                                      Breaking Dawn  ...       1070245
# 56                            The Secret Life of Bees  ...        916189
# 57                 The Adventures of Huckleberry Finn  ...        953758
# 58                                    Charlotte's Web  ...       1064521
# 59  The Curious Incident of the Dog in the Night-Time  ...        867553
# 60                              The Girl on the Train  ...       1008778
# 61                                    Northern Lights  ...        953970
# 62                                  Wuthering Heights  ...        899195
# 63                                 My Sister's Keeper  ...        863879
# 64  Slaughterhouse-Five, or The Children's Crusade...  ...        846488
# 65                                 Gone with the Wind  ...        873981
# 66                           A Thousand Splendid Suns  ...        818742
# 67                    The Perks of Being a Wallflower  ...        888806
# 68                                          Insurgent  ...        836362
# 69                                       Ender's Game  ...        813439
# 70            Frankenstein; or, The Modern Prometheus  ...        808589
# 71                                        The Shining  ...        791850
# 72                                           The Host  ...        749780
# 73                                 Looking for Alaska  ...        783470
# 74                                                NaN  ...        736498
# 75                              Sense and Sensibility  ...        738894
# 76                                              Holes  ...        747445
# 77                              The Devil Wears Prada  ...        665930
# 78                                  á½Î´ÏÏÏÎµÎ¹Î±  ...        670326
# 79                                    Le Petit Prince  ...        738757
# 80                                   The Glass Castle  ...        621099
# 81                                      Into the Wild  ...        647684
# 82                               A Tale of Two Cities  ...        637412
# 83                                      Jurassic Park  ...        447833
# 84                                    The Giving Tree  ...        702332
# 85                                     A Time to Kill  ...        597775
# 86                            Un di Velt Hot Geshvign  ...        691231
# 87                                        Paper Towns  ...        461311
# 88                                 The Princess Bride  ...        628637
# 89                                      The Outsiders  ...        659248
# 90                                    The Maze Runner  ...        719925
# 91  Freakonomics: A Rogue Economist Explores the H...  ...        524191
# 92                                  The Secret Garden  ...        639357
# 93                              Cien aÃ±os de soledad  ...        490565
# 94                         The Picture of Dorian Gray  ...        590014
# 95                                 Fifty Shades Freed  ...        387290
# 96                                            Dracula  ...        618973
# 97                        Flickan som lekte med elden  ...        563994
# 98                                Fifty Shades Darker  ...        552059
#
#    work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 49            1023781                     9234      16590      30792
# 50            1241799                    51589      34122      65349
# 51            1176642                    35216      83094     124293
# 52            1125231                    18280      50563      88536
# 53            1006479                    20345      21764      41962
# 54            1079135                    20095      26367      60328
# 55            1107709                    44550     100994     114893
# 56             937393                    26522      17500      45455
# 57            1001491                    12448      28467      76630
# 58            1084842                    13044      18450      41124
# 59             915790                    35796      21049      58117
# 60            1226485                    93600      27773      73897
# 61             994914                    14915      38382      64591
# 62            1001135                    26157      46469      84084
# 63             887880                    30719      17547      42763
# 64             891762                    19646      24964      45518
# 65             897303                    16050      19996      33136
# 66             866065                    43645       6509      18015
# 67             954905                    47116      14286      38658
# 68             947338                    55873      10641      44620
# 69             873417                    38054      15330      27612
# 70             883563                    19993      29366      74142
# 71             830881                    14936      18487      28981
# 72             777560                    39778      44215      62501
# 73             831285                    47128      16940      44232
# 74             754498                     8157      28973      59309
# 75             779382                    11526      18430      34699
# 76             764637                    15832      15495      43786
# 77             679845                     8024      24231      58323
# 78             710757                     8101      29703      65629
# 79             859286                    24537      15039      32866
# 80             637866                    40777       7901      18922
# 81             665377                    17299      19229      35567
# 82             677713                    13093      28904      55555
# 83             650483                     8143      15736      34222
# 84             708287                    14368      15345      20408
# 85             608824                     4239      12106      25938
# 86             707879                    22001       7761      18539
# 87             655271                    42717      14105      47183
# 88             658042                    15630      12883      21641
# 89             680437                    22662      10178      34346
# 90             777956                    48942      15291      43370
# 91             549301                    13668      14586      26538
# 92             692249                    13054       8005      25207
# 93             575667                    21671      27340      37646
# 94             674551                    19647       9825      30735
# 95             610116                    25287      39079      55691
# 96             689739                    17263      11756      36719
# 97             649253                    31423       4623      15781
# 98             623340                    28052      37245      58935
#
#     ratings_3  ratings_4  ratings_5  \
# 49     139024     293222     544153
# 50     203466     356048     582814
# 51     260763     309358     399134
# 52     240157     337943     408032
# 53     145173     299579     498001
# 54     219895     389379     383166
# 55     213402     267706     410714
# 56     185631     347540     341267
# 57     255722     344356     296316
# 58     191415     346090     487763
# 59     218218     355925     262481
# 60     273817     488447     362551
# 61     198764     313147     380030
# 62     215320     309180     346082
# 63     162573     314003     350994
# 64     152442     300948     367890
# 65     116160     234290     493721
# 66      99030     295817     446694
# 67     143440     297501     461020
# 68     182131     339977     369969
# 69     103439     264207     462829
# 70     231022     300495     248538
# 71     123862     277393     382158
# 72     154906     227180     288758
# 73     147324     262932     359857
# 74     198555     254836     212825
# 75     141987     272512     311754
# 76     176946     269153     259257
# 77     192366     226675     178250
# 78     183082     224120     208223
# 79     114714     228440     468227
# 80      85191     227750     298102
# 81     135199     248287     227095
# 82     153305     216378     223571
# 83     138327     231583     230615
# 84      76071     167542     428921
# 85     122675     218617     229488
# 86      90575     230227     360777
# 87     154479     223895     215609
# 88      89236     196047     338235
# 89     134244     227250     274419
# 90     150488     266698     302109
# 91     115789     216316     176072
# 92     129646     243821     285570
# 93      87675     155809     267197
# 94     129420     246892     257679
# 95     109963     140304     265079
# 96     151396     246043     243825
# 97      91021     258236     279592
# 98     114203     150906     262051
#
#                                             image_url  \
# 49  https://images.gr-assets.com/books/1168052448m...
# 50  https://images.gr-assets.com/books/1432730315m...
# 51  https://images.gr-assets.com/books/1361038355m...
# 52  https://images.gr-assets.com/books/1366212852m...
# 53  https://images.gr-assets.com/books/1327656754m...
# 54  https://images.gr-assets.com/books/1487389574m...
# 55  https://images.gr-assets.com/books/1361039438m...
# 56  https://images.gr-assets.com/books/1473454532m...
# 57  https://images.gr-assets.com/books/1405973850m...
# 58  https://images.gr-assets.com/books/1439632243m...
# 59  https://images.gr-assets.com/books/1479863624m...
# 60  https://images.gr-assets.com/books/1490903702m...
# 61  https://images.gr-assets.com/books/1451271747m...
# 62  https://s.gr-assets.com/assets/nophoto/book/11...
# 63  https://images.gr-assets.com/books/1369504683m...
# 64  https://images.gr-assets.com/books/1440319389m...
# 65  https://images.gr-assets.com/books/1328025229m...
# 66  https://images.gr-assets.com/books/1345958969m...
# 67  https://images.gr-assets.com/books/1167352178m...
# 68  https://images.gr-assets.com/books/1325667729m...
# 69  https://images.gr-assets.com/books/1408303130m...
# 70  https://images.gr-assets.com/books/1381512375m...
# 71  https://images.gr-assets.com/books/1353277730m...
# 72  https://images.gr-assets.com/books/1318009171m...
# 73  https://images.gr-assets.com/books/1394798630m...
# 74  https://images.gr-assets.com/books/1292060045m...
# 75  https://images.gr-assets.com/books/1397245675m...
# 76  https://images.gr-assets.com/books/1327781893m...
# 77  https://s.gr-assets.com/assets/nophoto/book/11...
# 78  https://images.gr-assets.com/books/1390173285m...
# 79  https://images.gr-assets.com/books/1367545443m...
# 80  https://images.gr-assets.com/books/1400930557m...
# 81  https://images.gr-assets.com/books/1403173986m...
# 82  https://images.gr-assets.com/books/1344922523m...
# 83  https://s.gr-assets.com/assets/nophoto/book/11...
# 84  https://images.gr-assets.com/books/1174210942m...
# 85  https://s.gr-assets.com/assets/nophoto/book/11...
# 86  https://images.gr-assets.com/books/1473495285m...
# 87  https://images.gr-assets.com/books/1349013610m...
# 88  https://images.gr-assets.com/books/1327903636m...
# 89  https://images.gr-assets.com/books/1442129426m...
# 90  https://images.gr-assets.com/books/1375596592m...
# 91  https://images.gr-assets.com/books/1327909092m...
# 92  https://images.gr-assets.com/books/1327873635m...
# 93  https://images.gr-assets.com/books/1327881361m...
# 94  https://images.gr-assets.com/books/1424596966m...
# 95  https://images.gr-assets.com/books/1336418837m...
# 96  https://images.gr-assets.com/books/1387151694m...
# 97  https://images.gr-assets.com/books/1351778881m...
# 98  https://images.gr-assets.com/books/1358266080m...
#
#                                       small_image_url
# 49  https://images.gr-assets.com/books/1168052448s...
# 50  https://images.gr-assets.com/books/1432730315s...
# 51  https://images.gr-assets.com/books/1361038355s...
# 52  https://images.gr-assets.com/books/1366212852s...
# 53  https://images.gr-assets.com/books/1327656754s...
# 54  https://images.gr-assets.com/books/1487389574s...
# 55  https://images.gr-assets.com/books/1361039438s...
# 56  https://images.gr-assets.com/books/1473454532s...
# 57  https://images.gr-assets.com/books/1405973850s...
# 58  https://images.gr-assets.com/books/1439632243s...
# 59  https://images.gr-assets.com/books/1479863624s...
# 60  https://images.gr-assets.com/books/1490903702s...
# 61  https://images.gr-assets.com/books/1451271747s...
# 62  https://s.gr-assets.com/assets/nophoto/book/50...
# 63  https://images.gr-assets.com/books/1369504683s...
# 64  https://images.gr-assets.com/books/1440319389s...
# 65  https://images.gr-assets.com/books/1328025229s...
# 66  https://images.gr-assets.com/books/1345958969s...
# 67  https://images.gr-assets.com/books/1167352178s...
# 68  https://images.gr-assets.com/books/1325667729s...
# 69  https://images.gr-assets.com/books/1408303130s...
# 70  https://images.gr-assets.com/books/1381512375s...
# 71  https://images.gr-assets.com/books/1353277730s...
# 72  https://images.gr-assets.com/books/1318009171s...
# 73  https://images.gr-assets.com/books/1394798630s...
# 74  https://images.gr-assets.com/books/1292060045s...
# 75  https://images.gr-assets.com/books/1397245675s...
# 76  https://images.gr-assets.com/books/1327781893s...
# 77  https://s.gr-assets.com/assets/nophoto/book/50...
# 78  https://images.gr-assets.com/books/1390173285s...
# 79  https://images.gr-assets.com/books/1367545443s...
# 80  https://images.gr-assets.com/books/1400930557s...
# 81  https://images.gr-assets.com/books/1403173986s...
# 82  https://images.gr-assets.com/books/1344922523s...
# 83  https://s.gr-assets.com/assets/nophoto/book/50...
# 84  https://images.gr-assets.com/books/1174210942s...
# 85  https://s.gr-assets.com/assets/nophoto/book/50...
# 86  https://images.gr-assets.com/books/1473495285s...
# 87  https://images.gr-assets.com/books/1349013610s...
# 88  https://images.gr-assets.com/books/1327903636s...
# 89  https://images.gr-assets.com/books/1442129426s...
# 90  https://images.gr-assets.com/books/1375596592s...
# 91  https://images.gr-assets.com/books/1327909092s...
# 92  https://images.gr-assets.com/books/1327873635s...
# 93  https://images.gr-assets.com/books/1327881361s...
# 94  https://images.gr-assets.com/books/1424596966s...
# 95  https://images.gr-assets.com/books/1336418837s...
# 96  https://images.gr-assets.com/books/1387151694s...
# 97  https://images.gr-assets.com/books/1351778881s...
# 98  https://images.gr-assets.com/books/1358266080s...
#
# [50 rows x 23 columns]

# %%
good_rat = pd.read_csv("Data/goodbooks-ratings.csv", encoding = 'latin-1', sep=',', low_memory=False, header=0)
good_rat.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %% [markdown]
# L'importazione dei file .csv è andata a buon fine, tuttavia nonostante l'utilizzo il tipo di encoding _Latin-1_ notiamo che vi sono dei caratteri che non sono stati decodificati nel modo corretto.

# %% [markdown]
# ### 1. Normalize the location field of *Users* dataset, splitting into city, region, country.

# %% [markdown]
# Verifichiamo di che tipo sia ogni valore:

# %%
type(users['Location'][0])
# Out:
# str

# %% [markdown]
# Si tratta di stringhe, perciò per dividere i campi si può utilizzare uno split.

# %% [markdown]
# Verifichiamo che per tutte le righe vi siano le tre informazioni necessarie:

# %%
cont=np.zeros(10,dtype=int)

for i, row in users.iterrows():
    lung = len(row['Location'].split(','))
    if lung == 1:
        cont[0]+=1
    elif lung == 2:
        cont[1]+=1
    elif lung == 3:
        cont[2]+=1
    elif lung == 4:
        cont[3]+=1
    elif lung == 5:
        cont[4]+=1
    elif lung == 6:
        cont[5]+=1
    elif lung == 7:
        cont[6]+=1
    elif lung == 8:
        cont[7]+=1
    elif lung == 9:
        cont[8]+=1
    else:
        cont[9]+=1
        
for i in range(0,10):
    if i==0:
        print('Righe con', i+1, 'elemento in Location:', cont[i])
    elif i==9:
         print('Righe con 0,10 o più elementi in Location:', cont[i])
    else:
        print('Righe con', i+1, 'elementi in Location:', cont[i])
# Out:
# Righe con 1 elemento in Location: 1
# Righe con 2 elementi in Location: 1
# Righe con 3 elementi in Location: 277348
# Righe con 4 elementi in Location: 1417
# Righe con 5 elementi in Location: 72
# Righe con 6 elementi in Location: 11
# Righe con 7 elementi in Location: 4
# Righe con 8 elementi in Location: 2
# Righe con 9 elementi in Location: 2
# Righe con 0,10 o più elementi in Location: 0

# %% [markdown]
# Il totale delle righe che non hanno l'esatto numero di elementi che ci servono sono

# %%
sbagliati = sum(cont)-cont[2]
sbagliati
# Out:
# 1510

# %% [markdown]
# Il numero totale di righe della tabella _users_ è

# %%
totale = users.shape[0]
totale
# Out:
# 278858

# %% [markdown]
# Perciò la percentuale di righe con informazioni mancanti o inesatte è del

# %%
print(round(sbagliati/totale, 3),'%')
# Out:
# 0.005 %

# %% [markdown]
# Osserviamo nello specifico alcune di queste osservazioni:

# %%
print(users.loc[6117]['Location'])
print(users.loc[12512]['Location'])
print(users.loc[6457]['Location'])
print(users.loc[3924]['Location'])
# Out:
# birmingham, alabama, alabama, usa
# nanaimo, bc, v9v 1h4, british columbia, canada
# mayfield, sussex (haha, you listed stroud!), united kingdom
# bombay, maharashtra, heard of it? :o), india

# %% [markdown]
# Alcune presentano valori ripetuti, senza significato o addirittura commenti personali.
#
# Decidiamo pertanto di eliminare tali osservazioni dal dataset, poiché ne rappresentano una piccola percentuale e poiché potrebbero essere portatrici di informazioni errate o superflue.

# %%
indici = []
for i, row in users.iterrows():
    lung = len(row['Location'].split(','))
    if lung != 3:
        indici.append(i)
        
users = users.drop(indici, axis=0)
len(users)
# Out:
# 277348

# %% [markdown]
# Dunque il numero di osservazioni che consideriamo è 277348 e con queste possiamo ricavare le tre colonne richieste: _city, region_ e _country_.

# %%
users['city'] = users['Location'].str.split(expand=True, pat=',')[0]
users['region'] = users['Location'].str.split(expand=True, pat=',')[1]
users['country'] = users['Location'].str.split(expand=True, pat=',')[2]

# %%
users.head()
# Out:
#    User-ID                            Location   Age         city  \
# 0        1                  nyc, new york, usa   NaN          nyc
# 1        2           stockton, california, usa  18.0     stockton
# 2        3     moscow, yukon territory, russia   NaN       moscow
# 3        4           porto, v.n.gaia, portugal  17.0        porto
# 4        5  farnborough, hants, united kingdom   NaN  farnborough
#
#              region          country
# 0          new york              usa
# 1        california              usa
# 2   yukon territory           russia
# 3          v.n.gaia         portugal
# 4             hants   united kingdom

# %% [markdown]
# L'operazione è andata a buon fine.

# %% [markdown]
# ### 2. For each book in the *Books* dataset, compute its average rating.

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
book_rat.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')

# %% [markdown]
# Calcoliamo l'_average rating_ per ciascun libro della tabella _book_rat_ e poi operiamo un merge del risultato con la tabella _books_.

# %%
ave_rat = book_rat.groupby(['ISBN'])['Book-Rating'].mean()
ave_rat.head()
# Out:
# ISBN
#  0330299891    3.0
#  0375404120    1.5
#  0586045007    0.0
#  9022906116    3.5
#  9032803328    0.0
# Name: Book-Rating, dtype: float64

# %%
books= pd.merge(books, ave_rat, on='ISBN')
books.rename({'Book-Rating': 'Average-Rating'}, axis='columns', inplace=True)
books[['ISBN', 'Book-Title', 'Average-Rating']].head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#    Average-Rating
# 0        0.000000
# 1        4.928571
# 2        5.000000
# 3        4.272727
# 4        0.000000

# %% [markdown]
# ### 3. For each book in the *GoodBooks* dataset, compute its average rating.

# %% [markdown]
# Osserviamo i nomi di tutte le colonne del dataframe in questione:

# %%
good_book.columns
# Out:
# Index(['book_id', 'goodreads_book_id', 'best_book_id', 'work_id',
#        'books_count', 'isbn', 'isbn13', 'authors', 'original_publication_year',
#        'original_title', 'title', 'language_code', 'average_rating',
#        'ratings_count', 'work_ratings_count', 'work_text_reviews_count',
#        'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5',
#        'image_url', 'small_image_url'],
#       dtype='object')

# %% [markdown]
# Notiamo che vi è già una colonna _average_rating_, tuttavia proviamo a calcolare la media per verificare se i valori coincidono.
#
# -- Elisa : Consideriamo ad esempio gli elementi della riga con indice 0 --
#
# Sommiamo i valori delle colonne _ratings_1, ratings_2, ratings_3, ratings_4_ e _ratings_5_ per capire se come denominatore per la media debba essere utilizzato l'attributo _ratings_count_ oppure _work_ratings_count_.

# %%
print('Somma dei ratings: ', good_book['ratings_1'][0] + good_book['ratings_2'][0] + good_book['ratings_3'][0] + good_book['ratings_4'][0] + good_book['ratings_5'][0]) 
print('Ratings count: ', good_book['ratings_count'][0])
print('Work ratings count: ', good_book['work_ratings_count'][0])
# Out:
# Somma dei ratings:  4942365
# Ratings count:  4780653
# Work ratings count:  4942365

# %% [markdown]
# Capiamo che la somma delle 5 colonne di ratings è contenuta in _work_ratings_count_.
#
# Calcoliamo dunque la media:

# %%
good_book['media'] = (good_book['ratings_1'] + good_book['ratings_2']*2 + good_book['ratings_3']*3 + good_book['ratings_4']*4 +good_book['ratings_5']*5)/good_book['work_ratings_count']
good_book['media'] = round(good_book['media'], ndigits=2)

# %%
good_book[['isbn', 'original_title', 'media', 'average_rating']]
# Out:
#           isbn                            original_title  media  \
# 0    439023483                          The Hunger Games   4.34
# 1    439554934  Harry Potter and the Philosopher's Stone   4.44
# 2    316015849                                  Twilight   3.57
# 3     61120081                     To Kill a Mockingbird   4.25
# 4    743273567                          The Great Gatsby   3.89
# ..         ...                                       ...    ...
# 94   375751513                The Picture of Dorian Gray   4.06
# 95   345803507                        Fifty Shades Freed   3.88
# 96   393970124                                   Dracula   3.98
# 97   307269981               Flickan som lekte med elden   4.22
# 98  1612130585                       Fifty Shades Darker   3.87
#
#     average_rating
# 0             4.34
# 1             4.44
# 2             3.57
# 3             4.25
# 4             3.89
# ..             ...
# 94            4.06
# 95            3.88
# 96            3.98
# 97            4.22
# 98            3.87
#
# [99 rows x 4 columns]

# %% [markdown]
# Effettivamente i valori del nostro calcolo, _media,_ e della colonna _average_rating_ coincidono.

# %% [markdown]
# ### 4. Merge together all rows sharing the same book title, author and publisher. We will call the resulting datset `merged books`. The books that have not been merged together will not appear in `merged books`.

# %% [markdown]
# Con l'opzione _count_ otteniamo l'informazione circa quante osservazioni siamo state accorpate in ciascun gruppo di chiave _(Book-Title, Book-Author, Publisher)_.

# %%
merged_books = books.groupby(by=["Book-Title", "Book-Author", "Publisher"], as_index=False).count()
print(len(merged_books))
merged_books.head()
# Out:
# 264961
#                                           Book-Title       Book-Author  \
# 0   A Light in the Storm: The Civil War Diary of ...       Karen Hesse
# 1                              Always Have Popsicles    Rebecca Harvin
# 2               Apple Magic (The Collector's series)  Martina Boudreau
# 3   Ask Lily (Young Women of Faith: Lily Series, ...      Nancy N. Rue
# 4   Beyond IBM: Leadership Marketing and Finance ...        Lou Mobley
#
#                      Publisher  ISBN  Year-Of-Publication  Image-URL-S  \
# 0  Hyperion Books for Children     1                    1            1
# 1            Rebecca L. Harvin     1                    1            1
# 2           Amer Cooking Guild     1                    1            1
# 3                   Zonderkidz     1                    1            1
# 4       Teleonet, Incorporated     1                    1            1
#
#    Image-URL-M  Image-URL-L  Average-Rating
# 0            1            1               1
# 1            1            1               1
# 2            1            1               1
# 3            1            1               1
# 4            1            1               1

# %%
indici = merged_books[merged_books['ISBN'] == 1 ].index
merged_books.drop(indici, inplace=True)
print(len(merged_books))
merged_books.head()
# Out:
# 4686
#                                             Book-Title  \
# 41                           !%@ (A Nutshell handbook)
# 58   'A Hell of a Place to Lose a Cow': An American...
# 252  10,000 dreams interpreted: A dictionary of dreams
# 461                                   101 Famous Poems
# 709                 15 Houseplants Even You Can't Kill
#
#                  Book-Author                       Publisher  ISBN  \
# 41             Donnalyn Frey                        O'Reilly     2
# 58               Tim Brookes             National Geographic     2
# 252  Gustavus Hindman Miller       Barnes &amp; Nobles Books     2
# 461              Roy J. Cook  McGraw-Hill/Contemporary Books     3
# 709                Joe Elder               Berkley Pub Group     2
#
#      Year-Of-Publication  Image-URL-S  Image-URL-M  Image-URL-L  \
# 41                     2            2            2            2
# 58                     2            2            2            2
# 252                    2            2            2            2
# 461                    3            3            3            3
# 709                    2            2            2            2
#
#      Average-Rating
# 41                2
# 58                2
# 252               2
# 461               3
# 709               2

# %% [markdown]
# Così abbiamo ottenuto un dataframe contenente solo i 4686 libri che hanno avuto due o più edizioni.
#
# Infine, eliminiamo le colonne _ISBN, Year-Of-Publication, Image-URL-S, Image-URL-M, Image-URL-L, Average-Rating,_ poiché esse non risultano essere più informative.

# %%
merged_books = merged_books.drop(['ISBN', 'Year-Of-Publication', 'Image-URL-S', 'Image-URL-M', 'Image-URL-L', 'Average-Rating'], axis=1)
merged_books.head()
# Out:
#                                             Book-Title  \
# 41                           !%@ (A Nutshell handbook)
# 58   'A Hell of a Place to Lose a Cow': An American...
# 252  10,000 dreams interpreted: A dictionary of dreams
# 461                                   101 Famous Poems
# 709                 15 Houseplants Even You Can't Kill
#
#                  Book-Author                       Publisher
# 41             Donnalyn Frey                        O'Reilly
# 58               Tim Brookes             National Geographic
# 252  Gustavus Hindman Miller       Barnes &amp; Nobles Books
# 461              Roy J. Cook  McGraw-Hill/Contemporary Books
# 709                Joe Elder               Berkley Pub Group

# %% [markdown]
# ### 5. For each book in `merged books` compute its average rating.
#
# The average is computed considering all books in `books` that have been merged.

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L', 'Average-Rating'],
#       dtype='object')

# %%
merged_books.columns
# Out:
# Index(['Book-Title', 'Book-Author', 'Publisher'], dtype='object')

# %% [markdown]
# Facciamo un _left join_ tra le tabelle _merged_books_ e _books,_ in modo tale che vengano tenuti tutti i libri che hanno avuto almeno due edizioni, con le informazioni relative a ciascuna edizione in righe diverse del dataframe.

# %%
merged_books2 = merged_books.merge(books, on=['Book-Title', 'Book-Author', 'Publisher'], how='left')
merged_books2.head()
# Out:
#                                           Book-Title              Book-Author  \
# 0                          !%@ (A Nutshell handbook)            Donnalyn Frey
# 1                          !%@ (A Nutshell handbook)            Donnalyn Frey
# 2  'A Hell of a Place to Lose a Cow': An American...              Tim Brookes
# 3  'A Hell of a Place to Lose a Cow': An American...              Tim Brookes
# 4  10,000 dreams interpreted: A dictionary of dreams  Gustavus Hindman Miller
#
#                    Publisher        ISBN Year-Of-Publication  \
# 0                   O'Reilly  1565920465                1994
# 1                   O'Reilly  1565920317                1993
# 2        National Geographic  0792276833                2000
# 3        National Geographic  0792277295                2001
# 4  Barnes &amp; Nobles Books  1566196256                1995
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/1565920465.0...
# 1  http://images.amazon.com/images/P/1565920317.0...
# 2  http://images.amazon.com/images/P/0792276833.0...
# 3  http://images.amazon.com/images/P/0792277295.0...
# 4  http://images.amazon.com/images/P/1566196256.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/1565920465.0...
# 1  http://images.amazon.com/images/P/1565920317.0...
# 2  http://images.amazon.com/images/P/0792276833.0...
# 3  http://images.amazon.com/images/P/0792277295.0...
# 4  http://images.amazon.com/images/P/1566196256.0...
#
#                                          Image-URL-L  Average-Rating
# 0  http://images.amazon.com/images/P/1565920465.0...            0.00
# 1  http://images.amazon.com/images/P/1565920317.0...            6.00
# 2  http://images.amazon.com/images/P/0792276833.0...            0.00
# 3  http://images.amazon.com/images/P/0792277295.0...            3.40
# 4  http://images.amazon.com/images/P/1566196256.0...            7.25

# %% [markdown]
# Infine, possiamo calcolare l'_Average-Rating_ per le edizioni di ciascun libro.

# %%
ave_rat = merged_books2.groupby(['Book-Title', 'Book-Author', 'Publisher'])['Average-Rating'].mean()
merged_books = pd.merge(merged_books, ave_rat, on=['Book-Title', 'Book-Author', 'Publisher'])
merged_books.head()
# Out:
#                                           Book-Title              Book-Author  \
# 0                          !%@ (A Nutshell handbook)            Donnalyn Frey
# 1  'A Hell of a Place to Lose a Cow': An American...              Tim Brookes
# 2  10,000 dreams interpreted: A dictionary of dreams  Gustavus Hindman Miller
# 3                                   101 Famous Poems              Roy J. Cook
# 4                 15 Houseplants Even You Can't Kill                Joe Elder
#
#                         Publisher  Average-Rating
# 0                        O'Reilly        3.000000
# 1             National Geographic        1.700000
# 2       Barnes &amp; Nobles Books        6.958333
# 3  McGraw-Hill/Contemporary Books        3.111111
# 4               Berkley Pub Group        0.000000

# %% [markdown]
# ### 6. For each book in `merged books` compute the minimum and maximum of the average ratings over all corresponding books in the `books` dataset.
#
# Hence for each book in `merged books` we will have exactly two values (a minimum and a maximum)

# %% [markdown]
# Utilizziamo la tabella _merged_books2_ che contiene le diverse edizioni di ciascun libro di _merged_books._

# %%
minimi = merged_books2.groupby(['Book-Title', 'Book-Author', 'Publisher'], as_index=False)['Average-Rating'].min()
massimi = merged_books2.groupby(['Book-Title', 'Book-Author', 'Publisher'], as_index=False)['Average-Rating'].max()

minimi.rename({'Average-Rating': 'Minimum-Average-Rating'}, axis='columns', inplace=True)
massimi.rename({'Average-Rating': 'Maximum-Average-Rating'}, axis='columns', inplace=True)
massimi.head()
# Out:
#                                           Book-Title              Book-Author  \
# 0                          !%@ (A Nutshell handbook)            Donnalyn Frey
# 1  'A Hell of a Place to Lose a Cow': An American...              Tim Brookes
# 2  10,000 dreams interpreted: A dictionary of dreams  Gustavus Hindman Miller
# 3                                   101 Famous Poems              Roy J. Cook
# 4                 15 Houseplants Even You Can't Kill                Joe Elder
#
#                         Publisher  Maximum-Average-Rating
# 0                        O'Reilly                    6.00
# 1             National Geographic                    3.40
# 2       Barnes &amp; Nobles Books                    7.25
# 3  McGraw-Hill/Contemporary Books                    5.00
# 4               Berkley Pub Group                    0.00

# %%
merged_books = pd.merge(merged_books, minimi, on=['Book-Title', 'Book-Author', 'Publisher'])
merged_books = pd.merge(merged_books, massimi, on=['Book-Title', 'Book-Author', 'Publisher'])
merged_books.head()
# Out:
#                                           Book-Title              Book-Author  \
# 0                          !%@ (A Nutshell handbook)            Donnalyn Frey
# 1  'A Hell of a Place to Lose a Cow': An American...              Tim Brookes
# 2  10,000 dreams interpreted: A dictionary of dreams  Gustavus Hindman Miller
# 3                                   101 Famous Poems              Roy J. Cook
# 4                 15 Houseplants Even You Can't Kill                Joe Elder
#
#                         Publisher  Average-Rating  Minimum-Average-Rating  \
# 0                        O'Reilly        3.000000                0.000000
# 1             National Geographic        1.700000                0.000000
# 2       Barnes &amp; Nobles Books        6.958333                6.666667
# 3  McGraw-Hill/Contemporary Books        3.111111                0.000000
# 4               Berkley Pub Group        0.000000                0.000000
#
#    Maximum-Average-Rating
# 0                    6.00
# 1                    3.40
# 2                    7.25
# 3                    5.00
# 4                    0.00

# %% [markdown]
# ### 7. For each book in `goodbooks`, compute the list of its authors. Assuming that the number of reviews with a text (column `work_text_reviews_count`) is split equally among all authors, find for each authors the total number of reviews with a text. We will call this quantity the *shared number of reviews with a text*.

# %%
good_book['List-Of-Authors'] = good_book['authors'].str.split(',')
good_book[['book_id', 'original_title', 'authors', 'List-Of-Authors']].head()
# Out:
#    book_id                            original_title  \
# 0        1                          The Hunger Games
# 1        2  Harry Potter and the Philosopher's Stone
# 2        3                                  Twilight
# 3        4                     To Kill a Mockingbird
# 4        5                          The Great Gatsby
#
#                         authors                  List-Of-Authors
# 0               Suzanne Collins                [Suzanne Collins]
# 1  J.K. Rowling, Mary GrandPrÃ©  [J.K. Rowling,  Mary GrandPrÃ©]
# 2               Stephenie Meyer                [Stephenie Meyer]
# 3                    Harper Lee                     [Harper Lee]
# 4           F. Scott Fitzgerald            [F. Scott Fitzgerald]

# %%
import math

# %%
from gensim.parsing.preprocessing import strip_multiple_whitespaces
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-35-2fc888676021> in <module>
# ----> 1 from gensim.parsing.preprocessing import strip_multiple_whitespaces
#
# ModuleNotFoundError: No module named 'gensim'

# %%
autori = dict()
for ind, row in good_book.iterrows():
    lista = row['authors'].split(',')    #lista con 1 o più nomi
    for nome in lista:
        nome = nome.strip()
        #nome = strip_multiple_whitespaces(nome)
        if nome not in autori:
            autori[nome] = round(row['work_text_reviews_count']/len(lista), 3)
        else:
            autori[nome] += row['work_text_reviews_count']/len(lista)

# %%
shared_number_of_reviews_with_a_text_GB = autori
shared_number_of_reviews_with_a_text_GB
# Out:
# {'Suzanne Collins': 340066.0,
#  'J.K. Rowling': 136668.0,
#  'Mary GrandPrÃ©': 136668.0,
#  'Stephenie Meyer': 258573.0,
#  'Harper Lee': 72586.0,
#  'F. Scott Fitzgerald': 51992.0,
#  'John Green': 230584.0,
#  'J.R.R. Tolkien': 52986.0,
#  'J.D. Salinger': 44920.0,
#  'Dan Brown': 66672.0,
#  'Jane Austen': 52994.0,
#  'Khaled Hosseini': 103375.0,
#  'Veronica Roth': 156896.0,
#  'George Orwell': 50644.667,
#  'Erich Fromm': 15172.667,
#  'CelÃ¢l Ã\x9cster': 15172.667,
#  'Anne Frank': 6941.667,
#  'Eleanor Roosevelt': 6941.667,
#  'B.M. Mooyaart-Doubleday': 6941.667,
#  'Stieg Larsson': 46983.0,
#  'Reg Keeland': 46983.0,
#  'Rufus Beck': 12033.0,
#  'Alice Sebold': 36642.0,
#  'William Golding': 26886.0,
#  'William Shakespeare': 7389.0,
#  'Robert           Jackson': 7389.0,
#  'Gillian Flynn': 121614.0,
#  'Kathryn Stockett': 78204.0,
#  'John Steinbeck': 24642.0,
#  'Arthur Golden': 25605.0,
#  'E.L. James': 128776.0,
#  'Paulo Coelho': 27890.5,
#  'Alan R. Clarke': 27890.5,
#  'Lois Lowry': 54084.0,
#  'C.S. Lewis': 15186.0,
#  'Audrey Niffenegger': 43382.0,
#  'George R.R. Martin': 46205.0,
#  'Elizabeth Gilbert': 49714.0,
#  'Rick Riordan': 46006.0,
#  'Louisa May Alcott': 17090.0,
#  'Charlotte BrontÃ«': 15606.0,
#  'Michael Mason': 15606.0,
#  'Nicholas Sparks': 17279.0,
#  'Yann Martel': 42962.0,
#  'Sara Gruen': 55732.0,
#  'Markus Zusak': 93611.0,
#  'Ray Bradbury': 30694.0,
#  'Shel Silverstein': 23602.0,
#  'Cassandra Clare': 51589.0,
#  'Christopher Paolini': 18280.0,
#  'Douglas Adams': 20345.0,
#  'Aldous Huxley': 20095.0,
#  'Sue Monk Kidd': 26522.0,
#  'Mark Twain': 4149.333,
#  'John Seelye': 4149.333,
#  'Guy Cardwell': 4149.333,
#  'E.B. White': 4348.0,
#  'Garth Williams': 4348.0,
#  'Rosemary Wells': 4348.0,
#  'Mark Haddon': 35796.0,
#  'Paula Hawkins': 93600.0,
#  'Philip Pullman': 14915.0,
#  'Emily BrontÃ«': 13078.5,
#  'Richard J. Dunn': 13078.5,
#  'Jodi Picoult': 30719.0,
#  'Kurt Vonnegut Jr.': 19646.0,
#  'Margaret Mitchell': 16050.0,
#  'Stephen Chbosky': 47116.0,
#  'Orson Scott Card': 38054.0,
#  'Mary Wollstonecraft Shelley': 6664.333,
#  'Percy Bysshe Shelley': 6664.333,
#  'Maurice Hindle': 6664.333,
#  'Stephen King': 14936.0,
#  'Helen Fielding': 8157.0,
#  'Tony Tanner': 3842.0,
#  'Ros Ballaster': 3842.0,
#  'Louis Sachar': 15832.0,
#  'Lauren Weisberger': 8024.0,
#  'Homer': 1620.2,
#  'Robert Fagles': 1620.2,
#  'E.V. Rieu': 1620.2,
#  'FrÃ©dÃ©ric Mugler': 1620.2,
#  'Bernard Knox': 1620.2,
#  'Antoine de Saint-ExupÃ©ry': 6134.25,
#  'Richard Howard': 6134.25,
#  'Dom Marcos Barbosa': 6134.25,
#  'Melina Karakosta': 6134.25,
#  'Jeannette Walls': 40777.0,
#  'Jon Krakauer': 17299.0,
#  'Charles Dickens': 4364.333,
#  'Richard Maxwell': 4364.333,
#  'Hablot Knight Browne': 4364.333,
#  'Michael Crichton': 8143.0,
#  'John Grisham': 4239.0,
#  'Elie Wiesel': 11000.5,
#  'Marion Wiesel': 11000.5,
#  'William Goldman': 15630.0,
#  'S.E. Hinton': 22662.0,
#  'James Dashner': 48942.0,
#  'Steven D. Levitt': 6834.0,
#  'Stephen J. Dubner': 6834.0,
#  'Frances Hodgson Burnett': 13054.0,
#  'Gabriel GarcÃ\xada MÃ¡rquez': 10835.5,
#  'Gregory Rabassa': 10835.5,
#  'Oscar Wilde': 9823.5,
#  'Jeffrey Eugenides': 9823.5,
#  'Bram Stoker': 5754.333,
#  'Nina Auerbach': 5754.333,
#  'David J. Skal': 5754.333}

# %%
shared=pd.DataFrame(shared_number_of_reviews_with_a_text_GB.items())
shared.rename({0: "Author",1:"reviews"},axis='columns',inplace=True)
shared
# Out:
#                 Author     reviews
# 0      Suzanne Collins  340066.000
# 1         J.K. Rowling  136668.000
# 2       Mary GrandPrÃ©  136668.000
# 3      Stephenie Meyer  258573.000
# 4           Harper Lee   72586.000
# ..                 ...         ...
# 104        Oscar Wilde    9823.500
# 105  Jeffrey Eugenides    9823.500
# 106        Bram Stoker    5754.333
# 107      Nina Auerbach    5754.333
# 108      David J. Skal    5754.333
#
# [109 rows x 2 columns]

# %% [markdown]
# ### 8. For each year of publication, determine the author that has the largest value of the shared number of reviews with a text.

# %%
good_book.columns
# Out:
# Index(['book_id', 'goodreads_book_id', 'best_book_id', 'work_id',
#        'books_count', 'isbn', 'isbn13', 'authors', 'original_publication_year',
#        'original_title', 'title', 'language_code', 'average_rating',
#        'ratings_count', 'work_ratings_count', 'work_text_reviews_count',
#        'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5',
#        'image_url', 'small_image_url', 'media', 'List-Of-Authors'],
#       dtype='object')

# %% [markdown]
# Creiamo un dizionario in cui le chiavi sono gli anni e i valori sono le liste di autori che hanno pubblicato uno o più libri in quell'anno.

# %%
anni_autori = dict()
for i, row in good_book.iterrows():
    anno = int(row['original_publication_year'])
    if anno not in anni_autori:
        anni_autori[anno] = row['authors'].strip().split(',')
       # anni_autori[anno] = strip_multiple_whitespaces(row['authors'].strip()).split(',')
    else:
        anni_autori[anno].extend(row['authors'].strip().split(','))
        #anni_autori[anno].extend(strip_multiple_whitespaces(row['authors'].strip()).split(','))
        
anni_autori
# Out:
# {2008: ['Suzanne Collins', 'Stephenie Meyer', 'Stephenie Meyer', 'John Green'],
#  1997: ['J.K. Rowling', ' Mary GrandPrÃ©', 'Arthur Golden'],
#  2005: ['Stephenie Meyer',
#   'Stieg Larsson',
#   ' Reg Keeland',
#   'J.K. Rowling',
#   ' Mary GrandPrÃ©',
#   'Rick Riordan',
#   'Markus Zusak',
#   'John Green',
#   'Jeannette Walls',
#   'Steven D. Levitt',
#   ' Stephen J. Dubner'],
#  1960: ['Harper Lee'],
#  1925: ['F. Scott Fitzgerald'],
#  2012: ['John Green', 'Gillian Flynn', 'Veronica Roth', 'E.L. James'],
#  1937: ['J.R.R. Tolkien', 'John Steinbeck'],
#  1951: ['J.D. Salinger'],
#  2000: ['Dan Brown', 'J.K. Rowling', ' Mary GrandPrÃ©'],
#  1813: ['Jane Austen'],
#  2003: ['Khaled Hosseini',
#   'J.K. Rowling',
#   ' Mary GrandPrÃ©',
#   'Dan Brown',
#   'Audrey Niffenegger',
#   'Mark Haddon',
#   'Lauren Weisberger'],
#  2011: ['Veronica Roth', 'E.L. James', 'E.L. James'],
#  1949: ['George Orwell', ' Erich Fromm', ' CelÃ¢l Ã\x9cster'],
#  1945: ['George Orwell'],
#  1947: ['Anne Frank', ' Eleanor Roosevelt', ' B.M. Mooyaart-Doubleday'],
#  2009: ['Suzanne Collins', 'Kathryn Stockett', 'James Dashner'],
#  1999: ['J.K. Rowling', ' Mary GrandPrÃ©', ' Rufus Beck', 'Stephen Chbosky'],
#  1954: ['J.R.R. Tolkien', 'William Golding'],
#  2010: ['Suzanne Collins'],
#  2002: ['Alice Sebold', 'Christopher Paolini'],
#  1998: ['J.K. Rowling', ' Mary GrandPrÃ©', 'Louis Sachar', ' Louis Sachar'],
#  2007: ['J.K. Rowling',
#   ' Mary GrandPrÃ©',
#   'Cassandra Clare',
#   'Stephenie Meyer',
#   'Khaled Hosseini'],
#  1595: ['William Shakespeare', ' Robert           Jackson'],
#  1988: ['Paulo Coelho', ' Alan R. Clarke'],
#  1993: ['Lois Lowry'],
#  1950: ['C.S. Lewis'],
#  1996: ['George R.R. Martin',
#   'Nicholas Sparks',
#   'Helen Fielding',
#   'Jon Krakauer'],
#  2006: ['Elizabeth Gilbert',
#   'Sara Gruen',
#   'Stephenie Meyer',
#   'Stieg Larsson',
#   ' Reg Keeland'],
#  1868: ['Louisa May Alcott'],
#  1847: ['Charlotte BrontÃ«',
#   ' Michael Mason',
#   'Emily BrontÃ«',
#   ' Richard J. Dunn'],
#  2001: ['Yann Martel', 'Sue Monk Kidd'],
#  1953: ['Ray Bradbury'],
#  1974: ['Shel Silverstein'],
#  1979: ['Douglas Adams'],
#  1932: ['Aldous Huxley'],
#  1884: ['Mark Twain', ' John Seelye', ' Guy Cardwell'],
#  1952: ['E.B. White', ' Garth Williams', ' Rosemary Wells'],
#  2015: ['Paula Hawkins'],
#  1995: ['Philip Pullman'],
#  2004: ['Jodi Picoult'],
#  1969: ['Kurt Vonnegut Jr.'],
#  1936: ['Margaret Mitchell'],
#  1985: ['Orson Scott Card'],
#  1818: ['Mary Wollstonecraft Shelley',
#   ' Percy Bysshe Shelley',
#   ' Maurice Hindle'],
#  1977: ['Stephen King'],
#  1811: ['Jane Austen', ' Tony Tanner', ' Ros Ballaster'],
#  -720: ['Homer',
#   ' Robert Fagles',
#   ' E.V. Rieu',
#   ' FrÃ©dÃ©ric Mugler',
#   ' Bernard Knox'],
#  1946: ['Antoine de Saint-ExupÃ©ry',
#   ' Richard Howard',
#   ' Dom Marcos Barbosa',
#   ' Melina Karakosta'],
#  1859: ['Charles Dickens', ' Richard Maxwell', ' Hablot Knight Browne'],
#  1990: ['Michael Crichton'],
#  1964: ['Shel Silverstein'],
#  1989: ['John Grisham'],
#  1958: ['Elie Wiesel', ' Marion Wiesel'],
#  1973: ['William Goldman'],
#  1967: ['S.E. Hinton', 'Gabriel GarcÃ\xada MÃ¡rquez', ' Gregory Rabassa'],
#  1911: ['Frances Hodgson Burnett'],
#  1891: ['Oscar Wilde', ' Jeffrey Eugenides'],
#  1897: ['Bram Stoker', ' Nina Auerbach', ' David J. Skal']}

# %% [markdown]
# Da ogni lista eliminiamo i duplicati rendendola prima _set_ e poi nuovamente lista:

# %%
for key, value in anni_autori.items():
    anni_autori[key] = list(set(anni_autori[key]))
anni_autori
# Out:
# {2008: ['John Green', 'Suzanne Collins', 'Stephenie Meyer'],
#  1997: [' Mary GrandPrÃ©', 'J.K. Rowling', 'Arthur Golden'],
#  2005: [' Reg Keeland',
#   'Stephenie Meyer',
#   'John Green',
#   'Rick Riordan',
#   ' Stephen J. Dubner',
#   'J.K. Rowling',
#   'Jeannette Walls',
#   'Steven D. Levitt',
#   ' Mary GrandPrÃ©',
#   'Markus Zusak',
#   'Stieg Larsson'],
#  1960: ['Harper Lee'],
#  1925: ['F. Scott Fitzgerald'],
#  2012: ['John Green', 'Veronica Roth', 'E.L. James', 'Gillian Flynn'],
#  1937: ['John Steinbeck', 'J.R.R. Tolkien'],
#  1951: ['J.D. Salinger'],
#  2000: ['Dan Brown', ' Mary GrandPrÃ©', 'J.K. Rowling'],
#  1813: ['Jane Austen'],
#  2003: ['Khaled Hosseini',
#   'Mark Haddon',
#   'J.K. Rowling',
#   'Lauren Weisberger',
#   ' Mary GrandPrÃ©',
#   'Dan Brown',
#   'Audrey Niffenegger'],
#  2011: ['E.L. James', 'Veronica Roth'],
#  1949: [' Erich Fromm', ' CelÃ¢l Ã\x9cster', 'George Orwell'],
#  1945: ['George Orwell'],
#  1947: [' B.M. Mooyaart-Doubleday', ' Eleanor Roosevelt', 'Anne Frank'],
#  2009: ['James Dashner', 'Suzanne Collins', 'Kathryn Stockett'],
#  1999: [' Mary GrandPrÃ©', ' Rufus Beck', 'J.K. Rowling', 'Stephen Chbosky'],
#  1954: ['William Golding', 'J.R.R. Tolkien'],
#  2010: ['Suzanne Collins'],
#  2002: ['Alice Sebold', 'Christopher Paolini'],
#  1998: ['Louis Sachar', ' Mary GrandPrÃ©', 'J.K. Rowling', ' Louis Sachar'],
#  2007: ['Khaled Hosseini',
#   'Stephenie Meyer',
#   'J.K. Rowling',
#   ' Mary GrandPrÃ©',
#   'Cassandra Clare'],
#  1595: [' Robert           Jackson', 'William Shakespeare'],
#  1988: ['Paulo Coelho', ' Alan R. Clarke'],
#  1993: ['Lois Lowry'],
#  1950: ['C.S. Lewis'],
#  1996: ['Helen Fielding',
#   'Jon Krakauer',
#   'Nicholas Sparks',
#   'George R.R. Martin'],
#  2006: ['Elizabeth Gilbert',
#   ' Reg Keeland',
#   'Stephenie Meyer',
#   'Stieg Larsson',
#   'Sara Gruen'],
#  1868: ['Louisa May Alcott'],
#  1847: ['Charlotte BrontÃ«',
#   ' Michael Mason',
#   ' Richard J. Dunn',
#   'Emily BrontÃ«'],
#  2001: ['Yann Martel', 'Sue Monk Kidd'],
#  1953: ['Ray Bradbury'],
#  1974: ['Shel Silverstein'],
#  1979: ['Douglas Adams'],
#  1932: ['Aldous Huxley'],
#  1884: [' Guy Cardwell', 'Mark Twain', ' John Seelye'],
#  1952: ['E.B. White', ' Garth Williams', ' Rosemary Wells'],
#  2015: ['Paula Hawkins'],
#  1995: ['Philip Pullman'],
#  2004: ['Jodi Picoult'],
#  1969: ['Kurt Vonnegut Jr.'],
#  1936: ['Margaret Mitchell'],
#  1985: ['Orson Scott Card'],
#  1818: ['Mary Wollstonecraft Shelley',
#   ' Percy Bysshe Shelley',
#   ' Maurice Hindle'],
#  1977: ['Stephen King'],
#  1811: ['Jane Austen', ' Tony Tanner', ' Ros Ballaster'],
#  -720: [' Robert Fagles',
#   ' Bernard Knox',
#   ' E.V. Rieu',
#   ' FrÃ©dÃ©ric Mugler',
#   'Homer'],
#  1946: [' Dom Marcos Barbosa',
#   ' Richard Howard',
#   'Antoine de Saint-ExupÃ©ry',
#   ' Melina Karakosta'],
#  1859: [' Richard Maxwell', ' Hablot Knight Browne', 'Charles Dickens'],
#  1990: ['Michael Crichton'],
#  1964: ['Shel Silverstein'],
#  1989: ['John Grisham'],
#  1958: [' Marion Wiesel', 'Elie Wiesel'],
#  1973: ['William Goldman'],
#  1967: ['Gabriel GarcÃ\xada MÃ¡rquez', 'S.E. Hinton', ' Gregory Rabassa'],
#  1911: ['Frances Hodgson Burnett'],
#  1891: ['Oscar Wilde', ' Jeffrey Eugenides'],
#  1897: [' David J. Skal', ' Nina Auerbach', 'Bram Stoker']}

# %% [markdown]
# Osserviamo le chiavi del dizionario, che dovrebbero essere gli anni:

# %%
anni_autori.keys()
# Out:
# dict_keys([2008, 1997, 2005, 1960, 1925, 2012, 1937, 1951, 2000, 1813, 2003, 2011, 1949, 1945, 1947, 2009, 1999, 1954, 2010, 2002, 1998, 2007, 1595, 1988, 1993, 1950, 1996, 2006, 1868, 1847, 2001, 1953, 1974, 1979, 1932, 1884, 1952, 2015, 1995, 2004, 1969, 1936, 1985, 1818, 1977, 1811, -720, 1946, 1859, 1990, 1964, 1989, 1958, 1973, 1967, 1911, 1891, 1897])

# %% [markdown]
# Vi è un valore anomalo: -720. Osserviamo il titolo a cui è associato questo anno di pubblicazione.

# %%
good_book[good_book['original_publication_year']== -720]['original_title']
# Out:
# 78    á½Î´ÏÏÏÎµÎ¹Î±
# Name: original_title, dtype: object

# %% [markdown]
# Decidiamo di eliminarlo dal dizionario:

# %%
del anni_autori[-720]
anni_autori.keys()
# Out:
# dict_keys([2008, 1997, 2005, 1960, 1925, 2012, 1937, 1951, 2000, 1813, 2003, 2011, 1949, 1945, 1947, 2009, 1999, 1954, 2010, 2002, 1998, 2007, 1595, 1988, 1993, 1950, 1996, 2006, 1868, 1847, 2001, 1953, 1974, 1979, 1932, 1884, 1952, 2015, 1995, 2004, 1969, 1936, 1985, 1818, 1977, 1811, 1946, 1859, 1990, 1964, 1989, 1958, 1973, 1967, 1911, 1891, 1897])

# %% [markdown]
# Ora non notiamo valori anomali.
#
# Per ciascun anno estraiamo l'autore che ha il numero massimo di _shared_reviews_with_a_text._

# %%
anno_aut_max = dict()
for anno in anni_autori.keys():
    autori=anni_autori[anno]
    max=0
    vicitore=''
    for autore in autori:
        autore=autore.strip()
        #autore=strip_multiple_whitespaces(autore).strip()
        if shared_number_of_reviews_with_a_text_GB[autore]>max:
            max=shared_number_of_reviews_with_a_text_GB[autore]
            vincitore=autore
    anno_aut_max[anno]=vincitore
anno_aut_max
# Out:
# {2008: 'Suzanne Collins',
#  1997: 'Mary GrandPrÃ©',
#  2005: 'Stephenie Meyer',
#  1960: 'Harper Lee',
#  1925: 'F. Scott Fitzgerald',
#  2012: 'John Green',
#  1937: 'J.R.R. Tolkien',
#  1951: 'J.D. Salinger',
#  2000: 'Mary GrandPrÃ©',
#  1813: 'Jane Austen',
#  2003: 'J.K. Rowling',
#  2011: 'Veronica Roth',
#  1949: 'George Orwell',
#  1945: 'George Orwell',
#  1947: 'B.M. Mooyaart-Doubleday',
#  2009: 'Suzanne Collins',
#  1999: 'Mary GrandPrÃ©',
#  1954: 'J.R.R. Tolkien',
#  2010: 'Suzanne Collins',
#  2002: 'Alice Sebold',
#  1998: 'Mary GrandPrÃ©',
#  2007: 'Stephenie Meyer',
#  1595: 'Robert           Jackson',
#  1988: 'Paulo Coelho',
#  1993: 'Lois Lowry',
#  1950: 'C.S. Lewis',
#  1996: 'George R.R. Martin',
#  2006: 'Stephenie Meyer',
#  1868: 'Louisa May Alcott',
#  1847: 'Charlotte BrontÃ«',
#  2001: 'Yann Martel',
#  1953: 'Ray Bradbury',
#  1974: 'Shel Silverstein',
#  1979: 'Douglas Adams',
#  1932: 'Aldous Huxley',
#  1884: 'Guy Cardwell',
#  1952: 'E.B. White',
#  2015: 'Paula Hawkins',
#  1995: 'Philip Pullman',
#  2004: 'Jodi Picoult',
#  1969: 'Kurt Vonnegut Jr.',
#  1936: 'Margaret Mitchell',
#  1985: 'Orson Scott Card',
#  1818: 'Mary Wollstonecraft Shelley',
#  1977: 'Stephen King',
#  1811: 'Jane Austen',
#  1946: 'Dom Marcos Barbosa',
#  1859: 'Richard Maxwell',
#  1990: 'Michael Crichton',
#  1964: 'Shel Silverstein',
#  1989: 'John Grisham',
#  1958: 'Marion Wiesel',
#  1973: 'William Goldman',
#  1967: 'S.E. Hinton',
#  1911: 'Frances Hodgson Burnett',
#  1891: 'Oscar Wilde',
#  1897: 'David J. Skal'}

# %% [markdown]
# E gli associamo il numero di _shared_number_of_reviews_with_a_text:_

# %%
for key, value in anno_aut_max.items():
    numero = shared_number_of_reviews_with_a_text_GB[anno_aut_max[key]]
    tupla = anno_aut_max[key]+','+str(numero)
    anno_aut_max[key] = tupla
#anno_aut_max
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-5cb1c43be1ca> in <module>
#       1 for key, value in anno_aut_max.items():
# ----> 2     numero = shared_number_of_reviews_with_a_text_GB[anno_aut_max[key]]
#       3     tupla = anno_aut_max[key]+','+str(numero)
#       4     anno_aut_max[key] = tupla
#       5 #anno_aut_max
#
# KeyError: 'Suzanne Collins,340066.0'

# %%
anno_aut_max
best_author_of_the_year = pd.DataFrame(anno_aut_max.items())
best_author_of_the_year['Best-Author'] = best_author_of_the_year[1].str.split(expand=True, pat=',')[0]
best_author_of_the_year['Shared-Views-With-Text'] = best_author_of_the_year[1].str.split(expand=True, pat=',')[1]
best_author_of_the_year.drop(labels=[1], axis=1, inplace=True)
best_author_of_the_year.rename({0: 'Year'}, axis='columns', inplace=True)
best_author_of_the_year.sort_values(by='Year', axis=0, ascending=True, inplace=True)
best_author_of_the_year.tail(15)
# Out:
#     Year      Best-Author Shared-Views-With-Text
# 16  1999   Mary GrandPrÃ©               136668.0
# 8   2000   Mary GrandPrÃ©               136668.0
# 30  2001      Yann Martel                42962.0
# 19  2002     Alice Sebold                36642.0
# 10  2003     J.K. Rowling               136668.0
# 39  2004     Jodi Picoult                30719.0
# 2   2005  Stephenie Meyer               258573.0
# 27  2006  Stephenie Meyer               258573.0
# 21  2007  Stephenie Meyer               258573.0
# 0   2008  Suzanne Collins               340066.0
# 15  2009  Suzanne Collins               340066.0
# 18  2010  Suzanne Collins               340066.0
# 11  2011    Veronica Roth               156896.0
# 5   2012       John Green               230584.0
# 37  2015    Paula Hawkins                93600.0

# %% [markdown]
# ### 9. Assuming that there are no errors in the ISBN fields, find the books in both datasets, and compute the difference of average rating according to the ratings and the goodratings datasets

# %% [markdown]
# Abbiamo già calcolato nei punti precedenti l'_average_rating_ per i libri dei dataset _books_ e _good_book,_ perciò utilizziamo per questo calcolo le colonne delle tabelle che si chiamano, rispettivamente per _books_ e _good_book, Average-Rating_ e _average_rating._

# %%
intersection = pd.merge(books, good_book, left_on='ISBN', right_on='isbn') #how=inner è il default
intersection.rename({'Average-Rating': 'Average-Rating-B', 'average_rating': 'Average-Rating-GB'}, axis='columns', inplace=True)
intersection['Difference-Of-Ratings'] = intersection['Average-Rating-B'] - intersection['Average-Rating-GB']
intersection[['ISBN', 'Book-Title', 'Average-Rating-B', 'Average-Rating-GB', 'Difference-Of-Ratings']]

# %% [markdown]
# ### 10. Split the users dataset according to the age. One dataset contains the users with unknown age, one with age 0-14, one with age 15-24, one with age 25-34, and so on.

# %% [markdown]
# Controlliamo se vi sono valori _null_ per il campo _Age_ del dataset _users._

# %%
print(len(users))
len(users[users['Age'].isnull()])

# %% [markdown]
# Nel dataset _users,_ su 277348 osservazioni 110204 presentano un valore nullo _(NaN)_ per il campo _Age._

# %% [markdown]
# Definiamo una funzione che estrae dal dataset _users_ le osservazioni che hanno un valore di _Age_ compreso tra due valori dati.

# %%
def crea_dataset(a,b):
    dataset=users[(users['Age']>=a)&(users['Age']<=b)]
    return dataset

# %% [markdown]
# Per applicarla, verifichiamo quale sia il massimo valore assunto dalla variabile _Age_ nel dataset.

# %%
users['Age'].sort_values(ascending=False).head(15)

# %% [markdown]
# Ad un primo impatto si tratta di valori molto strani per quello che rappresentano, tuttavia non abbiamo la sicurezza che l'unità di misura utilizzata sia 'anni', anche se lo ipotizziamo. Verifichiamo quante osservazioni presentino valori più elevati di una simbolica età di 100 anni, per capire se essi possono essere considerati come valori anomali o _outliers_ che si possono eliminare dal dataset.

# %%
len(users[users['Age']>=101])

# %%
sopra_101=len(users[users['Age']>=101])
totali=len(users)

# %%
print(round(sopra_101/totali,3),'%')

# %% [markdown]
# Le osservazioni che presentano nel campo _Age_ un valore anomalo, maggiore della soglia simbolica dei 100 anni, sono 364. Poiché rappresentano una piccolissima parte del totale delle osservazioni, lo 0.001%, decidiamo di non considerare nella creazione di dataset per intervalli di 10 anni di età le osservazioni che presentano valori maggiori di 105.

# %% [markdown]
# Definiamo dunque i dataset richiesti:

# %%
users_0_14 = crea_dataset(0,14)
users_15_24 = crea_dataset(15,24)
users_25_34 = crea_dataset(25,34)
users_35_44 = crea_dataset(35,44)
users_45_54 = crea_dataset(45,54)
users_55_64 = crea_dataset(55,64)
users_65_74 = crea_dataset(65,74)
users_75_84 = crea_dataset(75,84)
users_85_94 = crea_dataset(85,94)
users_95_104 = crea_dataset(95,104)

# %% [markdown]
# E ne stampiamo uno di esempio:

# %%
users_35_44.head()

# %% [markdown]
# ### 11. Find the books that appear only in the goodbooks datasets.

# %% [markdown]
# Effettuiamo una _merge_ dei due dataset con le seguenti opzioni:
# - _how = outer,_ che permette di considerare anche gli elementi che si trovano in uno solo dei due dataset che si uniscono;
# - _indicator = True,_ che crea una variabile indicante in quale dei due dataset si trovasse l'osservazione _(left_only, right_only, both)._ Questa opzione ci permette successivamente di selezionare le osservazioni che si trovavano solo nel dataset _good_books,_ ovvero quello di destra.

# %%
union = pd.merge(books, good_book, left_on='ISBN', right_on='isbn', how='outer', indicator=True)
union[['ISBN','Book-Title','Book-Author','_merge']].head()

# %%
isbn_only_gb = union[union['_merge'] == 'right_only'][['isbn']]
isbn_only_gb.head()

# %% [markdown]
# Una volta ottenuto un dataframe che contiene unicamente gli _isbn_ dei libri che si trovano solo in _good_book,_ effettuiamo un _inner join_ per estrarre e visualizzare anche il titolo e gli autori di ciascun libro.

# %%
books_only_gb = pd.merge(good_book, isbn_only_gb, on='isbn', how='inner')
books_only_gb[['isbn', 'original_title', 'authors']].head()

# %% [markdown]
# ### 12. Assuming that each pair (author, title) identifies a book, for each book find the number of times it appears in the books dataset. Which books appear the most times?

# %% [markdown]
# Per rispondere a questo quesito utilizziamo la funzione _groupby_ rispetto alla coppia _(Book-Author, Book-Title),_ conteggiamo la frequenza delle osservazioni e poi le ordiniamo per conteggio in ordine decrescente, per osservare il libro che appare più frequentemente

# %%
grouped = books.groupby(['Book-Author', 'Book-Title'], as_index=False).count().sort_values(['ISBN'], ascending=False)
grouped.rename({'ISBN': 'Count'}, axis='columns', inplace=True)
grouped[['Book-Author', 'Book-Title', 'Count']].head()

# %% [markdown]
# Il libro che appare più frequentemente è _Little Women_ di Louisa May Alcott, per un totale di 21 volte.

# %% [markdown]
# ### 13. Find the author with the highest average rating according to the goodbooks datasets.

# %% [markdown]
# Creiamo un dizionario nel quale al nome di ciascun autore è associata una lista con i diversi ratings che ha ottenuto.

# %%
autori_ratings = dict()
for i, row in good_book.iterrows():
    autori=row['authors'].split(',')
    for autore in autori:
        autore=autore.strip()
      #  autore=strip_multiple_whitespaces(autore)
        if autore not in autori_ratings:
            autori_ratings[autore] = []
        autori_ratings[autore].append(row['average_rating'])
autori_ratings

# %% [markdown]
# Successivamente, sostituiamo a ciascuna lista la media dei valori che contiene:

# %%
import statistics

for key, value in autori_ratings.items():
    media = statistics.mean(value)
    autori_ratings[key] = media

# %%
autori_ratings

# %% [markdown]
# Ed infine estraiamo l'autore che presenta il rating medio più alto.

# %%
max(autori_ratings, key=autori_ratings.get)

# %% [markdown]
# Con un _average_rating_ pari a:

# %%
autori_ratings[max(autori_ratings, key=autori_ratings.get)]
